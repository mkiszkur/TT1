# %% [markdown]
# # Setup

# %%
from pathlib import Path

# Obtén el directorio actual de trabajo
current_dir = Path.cwd()
print("Current directory:", current_dir)

# Ir un nivel arriba y luego a la carpeta 'data'
parent_dir = current_dir.parent
path_data = parent_dir / 'data'
# Out:
# Current directory: /Users/miguelkiszkurno/Documents/TT1/03_eda

# %% [markdown]
# # Revision de ratios

# %% [markdown]
# ## combined_indicators_area_anho_indicador

# %%
import pandas as pd

# Cargar el dataset
file_path = path_data / 'combined_indicators_area_anho_indicador.csv'

data = pd.read_csv(file_path)

import holoviews as hv
import panel as pn
from bokeh.models import CustomJS, MultiSelect
hv.extension('bokeh')
pn.extension()

# Crear un selector para file_name
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.Select(name='File Name', options=file_names)

# Crear un selector para indicators
indicators = list(data['indicator'].unique())
indicator_select = pn.widgets.MultiSelect(name='Indicators', options=indicators, size=10)

# Función para actualizar el heatmap
@pn.depends(file_name_select.param.value, indicator_select.param.value)
def update_heatmap(file_name, selected_indicators):
    filtered_data = data[data['file_name'] == file_name]
    if selected_indicators:
        filtered_data = filtered_data[filtered_data['indicator'].isin(selected_indicators)]
    heatmap = hv.HeatMap(filtered_data, kdims=['anho', 'indicator'], vdims=['ratio_ones'])
    heatmap = heatmap.opts(
        cmap='Viridis', 
        colorbar=True, 
        width=900, 
        height=600, 
        xlabel='Año', 
        ylabel='Indicador', 
        tools=['hover'],
        xrotation=45
    )
    return heatmap

# Layout
layout = pn.Column(
    pn.Row(file_name_select, indicator_select),
    update_heatmap
)

# Mostrar el layout
layout.servable()
layout.show() # Esto es para mostrarlo directamente en el notebook
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='84780667-1cdf-4a70-89de-6e7299dea41d'>
#   <div id="f797f659-42d3-40c9-be2d-94ac13c234a9" data-root-id="84780667-1cdf-4a70-89de-6e7299dea41d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"23b53e9b-349e-41d0-a142-91d658552a6b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"84780667-1cdf-4a70-89de-6e7299dea41d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"3cb6eb31-1d9e-401d-aa6e-45a98a945e41","attributes":{"plot_id":"84780667-1cdf-4a70-89de-6e7299dea41d","comm_id":"490974a38b8d4821815342829e6e58cc","client_comm_id":"ab2153a37e6d47ee83cc0819a87e6112"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"23b53e9b-349e-41d0-a142-91d658552a6b","roots":{"84780667-1cdf-4a70-89de-6e7299dea41d":"f797f659-42d3-40c9-be2d-94ac13c234a9"},"root_ids":["84780667-1cdf-4a70-89de-6e7299dea41d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Launching server at http://localhost:50367

# %%
data
# Out:
#                               file_name  anho          indicator  ratio_ones
# 0       Agriculture & Rural Development  1960     AG.AGR.TRAC.NO    0.000000
# 1       Agriculture & Rural Development  1960  AG.CON.FERT.PT.ZS    0.000000
# 2       Agriculture & Rural Development  1960     AG.CON.FERT.ZS    0.000000
# 3       Agriculture & Rural Development  1960     AG.LND.AGRI.K2    0.000000
# 4       Agriculture & Rural Development  1960     AG.LND.AGRI.ZS    0.000000
# ...                                 ...   ...                ...         ...
# 133435                Urban Development  2023  EN.URB.LCTY.UR.ZS    0.701835
# 133436                Urban Development  2023  EN.URB.MCTY.TL.ZS    0.555046
# 133437                Urban Development  2023     SH.STA.TRAF.P5    0.000000
# 133438                Urban Development  2023        SP.URB.GROW    0.000000
# 133439                Urban Development  2023  SP.URB.TOTL.IN.ZS    0.000000
#
# [133440 rows x 4 columns]

# %%
df_indicators = data.copy()

df_indicators = df_indicators[df_indicators['anho'] <= 2022]

df_indicators[df_indicators['indicator']=='SP.RUR.TOTL.ZS']
# Out:
#                             file_name  anho       indicator  ratio_ones
# 39    Agriculture & Rural Development  1960  SP.RUR.TOTL.ZS    0.986239
# 81    Agriculture & Rural Development  1961  SP.RUR.TOTL.ZS    0.986239
# 123   Agriculture & Rural Development  1962  SP.RUR.TOTL.ZS    0.986239
# 165   Agriculture & Rural Development  1963  SP.RUR.TOTL.ZS    0.986239
# 207   Agriculture & Rural Development  1964  SP.RUR.TOTL.ZS    0.986239
# ...                               ...   ...             ...         ...
# 2475  Agriculture & Rural Development  2018  SP.RUR.TOTL.ZS    0.986239
# 2517  Agriculture & Rural Development  2019  SP.RUR.TOTL.ZS    0.986239
# 2559  Agriculture & Rural Development  2020  SP.RUR.TOTL.ZS    0.986239
# 2601  Agriculture & Rural Development  2021  SP.RUR.TOTL.ZS    0.986239
# 2643  Agriculture & Rural Development  2022  SP.RUR.TOTL.ZS    0.986239
#
# [63 rows x 4 columns]

# %%
### Cuenta la cantidad de indicatdores que tienen ratio mayor que alpha por año.###


alpha = 0.95

df_indicators = data.copy()
df_indicators = df_indicators[df_indicators['anho'] <= 2022]


# Convertir la columna 'anho' a tipo entero
df_indicators['anho'] = df_indicators['anho'].astype(int)


# Agrupar por indicador y filtrar aquellos que cumplen la condición en todos sus registros
#indicators = df_indicators.groupby('indicator').filter(lambda x: (x['ratio_ones'] >= alpha).all())['indicator'].unique()
#indicators

# Filtrar los datos y contar los indicadores válidos año por año
for x in range(1960, 2022):
    # Filtrar los datos para incluir solo los años desde x en adelante
    df_indicators = df_indicators[df_indicators['anho'] >= x]

    # Agrupar por indicador y filtrar aquellos que cumplen la condición en todos sus registros
    indicators = df_indicators.groupby('indicator').filter(lambda x: (x['ratio_ones'] >= alpha).all())['indicator'].unique()
    
    
    # Contar el número de indicadores únicos que cumplen con la condición
    cant = indicators.shape[0]
    
    # Imprimir el resultado
    print(f'{x}: {cant}')
# Out:
# 1960: 65
# 1961: 67
# 1962: 67
# 1963: 67
# 1964: 67
# 1965: 67
# 1966: 67
# 1967: 67
# 1968: 67
# 1969: 67
# 1970: 67
# 1971: 67
# 1972: 67
# 1973: 67
# 1974: 67
# 1975: 67
# 1976: 67
# 1977: 67
# 1978: 67
# 1979: 67
# 1980: 67
# 1981: 67
# 1982: 67
# 1983: 67
# 1984: 67
# 1985: 67
# 1986: 67
# 1987: 67
# 1988: 67
# 1989: 67
# 1990: 67
# 1991: 67
# 1992: 67
# 1993: 67
# 1994: 67
# 1995: 67
# 1996: 67
# 1997: 67
# 1998: 67
# 1999: 67
# 2000: 67
# 2001: 67
# 2002: 68
# 2003: 68
# 2004: 69
# 2005: 70
# 2006: 70
# 2007: 70
# 2008: 70
# 2009: 70
# 2010: 71
# 2011: 71
# 2012: 71
# 2013: 71
# 2014: 71
# 2015: 71
# 2016: 74
# 2017: 76
# 2018: 77
# 2019: 77
# 2020: 77
# 2021: 77

# %%
def filtrar_dataset_por_anho_y_alpha(data, anho, alpha):
    df_indicators = data.copy()
    df_indicators = df_indicators[df_indicators['anho'] <= 2022]
    df_indicators = df_indicators[df_indicators['anho'] >= anho]

    # Convertir la columna 'anho' a tipo entero
    df_indicators['anho'] = df_indicators['anho'].astype(int)
    indicators = pd.DataFrame(df_indicators.groupby('indicator').filter(lambda x: (x['ratio_ones'] >= alpha).all())['indicator'].unique())
    indicators.columns = ['code']

    indicadores_path = path_data / 'merged_resultados_indicadores.csv'
    
    df_indicadores = pd.read_csv(indicadores_path)

    # Realizar el merge usando el campo codigo_indicador en resultados y INDICATOR_CODE en indicadores
    merged_data = pd.merge(indicators, df_indicadores, left_on='code', right_on='INDICATOR_CODE', how='inner')
    merged_data.to_csv(path_data / f'indicadores_filtrados_{anho}.csv', index=False)
    return merged_data

d = filtrar_dataset_por_anho_y_alpha(data, 2022, 0.95)
d
# Out:
#                  code                   titulo_seccion   codigo_indicador  \
# 0         SP.RUR.TOTL  Agriculture & Rural Development        SP.RUR.TOTL
# 1      SP.RUR.TOTL.ZS  Agriculture & Rural Development     SP.RUR.TOTL.ZS
# 2         SH.TBS.INCD                Aid Effectiveness        SH.TBS.INCD
# 3         SH.TBS.INCD                           Health        SH.TBS.INCD
# 4         SM.POP.NETM                Aid Effectiveness        SM.POP.NETM
# ..                ...                              ...                ...
# 92  SP.POP.TOTL.FE.ZS                           Health  SP.POP.TOTL.FE.ZS
# 93  SP.POP.TOTL.MA.IN                           Health  SP.POP.TOTL.MA.IN
# 94  SP.POP.TOTL.MA.ZS                           Health  SP.POP.TOTL.MA.ZS
# 95        IQ.SPI.PIL1                    Public Sector        IQ.SPI.PIL1
# 96        IQ.SPI.PIL3                    Public Sector        IQ.SPI.PIL3
#
#                                 descripcion_indicador  Unnamed: 3  \
# 0                                    Rural population  descargado
# 1            Rural population (% of total population)  descargado
# 2      Incidence of tuberculosis (per 100,000 people)  descargado
# 3      Incidence of tuberculosis (per 100,000 people)  descargado
# 4                                       Net migration  descargado
# ..                                                ...         ...
# 92         Population, female (% of total population)  descargado
# 93                                   Population, male  descargado
# 94           Population, male (% of total population)  descargado
# 95  Statistical performance indicators (SPI): Pill...  descargado
# 96  Statistical performance indicators (SPI): Pill...  descargado
#
#                                                estado direccion  \
# 0   https://data.worldbank.org/indicator/SP.RUR.TO...       NaN
# 1   https://data.worldbank.org/indicator/SP.RUR.TO...       NaN
# 2   https://data.worldbank.org/indicator/SH.TBS.IN...       NaN
# 3   https://data.worldbank.org/indicator/SH.TBS.IN...       NaN
# 4   https://data.worldbank.org/indicator/SM.POP.NE...       NaN
# ..                                                ...       ...
# 92  https://data.worldbank.org/indicator/SP.POP.TO...       NaN
# 93  https://data.worldbank.org/indicator/SP.POP.TO...       NaN
# 94  https://data.worldbank.org/indicator/SP.POP.TO...       NaN
# 95  https://data.worldbank.org/indicator/IQ.SPI.PI...       NaN
# 96  https://data.worldbank.org/indicator/IQ.SPI.PI...       NaN
#
#        INDICATOR_CODE                                          FILE_NAME  \
# 0         SP.RUR.TOTL  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 1      SP.RUR.TOTL.ZS  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 2         SH.TBS.INCD  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 3         SH.TBS.INCD  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 4         SM.POP.NETM  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# ..                ...                                                ...
# 92  SP.POP.TOTL.FE.ZS  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 93  SP.POP.TOTL.MA.IN  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 94  SP.POP.TOTL.MA.ZS  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 95        IQ.SPI.PIL1  /Users/miguelkiszkurno/Documents/TT1/data/API_...
# 96        IQ.SPI.PIL3  /Users/miguelkiszkurno/Documents/TT1/data/API_...
#
#                                        INDICATOR_NAME  \
# 0                                    Rural population
# 1            Rural population (% of total population)
# 2      Incidence of tuberculosis (per 100,000 people)
# 3      Incidence of tuberculosis (per 100,000 people)
# 4                                       Net migration
# ..                                                ...
# 92         Population, female (% of total population)
# 93                                   Population, male
# 94           Population, male (% of total population)
# 95  Statistical performance indicators (SPI): Pill...
# 96  Statistical performance indicators (SPI): Pill...
#
#                                           SOURCE_NOTE  \
# 0   Rural population refers to people living in ru...
# 1   Rural population refers to people living in ru...
# 2   Incidence of tuberculosis is the estimated num...
# 3   Incidence of tuberculosis is the estimated num...
# 4   Net migration is the net total of migrants dur...
# ..                                                ...
# 92  Female population is the percentage of the pop...
# 93  Male population is based on the de facto defin...
# 94  Male population is the percentage of the popul...
# 95  The data use overall score is a composite scor...
# 96  The data products overall score is a composite...
#
#                                   SOURCE_ORGANIZATION
# 0   World Bank staff estimates based on the United...
# 1   World Bank staff estimates based on the United...
# 2   World Health Organization, Global Tuberculosis...
# 3   World Health Organization, Global Tuberculosis...
# 4   United Nations Population Division. World Popu...
# ..                                                ...
# 92  World Bank staff estimates based on age/sex di...
# 93  World Bank staff estimates using the World Ban...
# 94  World Bank staff estimates based on age/sex di...
# 95  Statistical Performance Indicators, The World ...
# 96  Statistical Performance Indicators, The World ...
#
# [97 rows x 12 columns]

# %%
import pandas as pd
import holoviews as hv
import panel as pn
from bokeh.models import CustomJS, MultiSelect

hv.extension('bokeh')

# Cargar el dataset
file_path = path_data / 'combined_indicators_area_ano.csv'
data = pd.read_csv(file_path)

# Crear un selector para file_name
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.Select(name='File Name', options=file_names)

# Función para actualizar el gráfico de líneas
@pn.depends(file_name_select.param.value)
def update_plot(file_name):
    filtered_data = data[data['file_name'] == file_name]
    curve = hv.Curve(filtered_data, kdims=['anho'], vdims=['ratio_ones'], label=file_name)
    curve = curve.opts(
        xlabel='Año', 
        ylabel='Ratio Ones', 
        title=f'Ratio Ones por Año para {file_name}',
        tools=['hover'],
        height=400, 
        width=900
    )
    return curve

# Layout
layout = pn.Column(
    file_name_select,
    update_plot
)

# Mostrar el layout
layout.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a196a48c-4d3f-42d2-8ded-60e46dfe2b7f'>
#   <div id="e729ae3a-fc89-4eb4-b496-36e30b837260" data-root-id="a196a48c-4d3f-42d2-8ded-60e46dfe2b7f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0f019c46-89db-4b2a-9f2f-8597f000c710":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a196a48c-4d3f-42d2-8ded-60e46dfe2b7f"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"a12065f3-6e76-4319-bc2d-214a51dc6aa7","attributes":{"plot_id":"a196a48c-4d3f-42d2-8ded-60e46dfe2b7f","comm_id":"b6bbe30547ba4ba99943ed8bc3dc4317","client_comm_id":"f49fd1f0a3164c89917be3a60e7d9adf"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"0f019c46-89db-4b2a-9f2f-8597f000c710","roots":{"a196a48c-4d3f-42d2-8ded-60e46dfe2b7f":"e729ae3a-fc89-4eb4-b496-36e30b837260"},"root_ids":["a196a48c-4d3f-42d2-8ded-60e46dfe2b7f"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'2947ca6c-7080-432e-affe-8f1a2b11aab5': {'version…

# %%
alpha = 0.95
filtered_data = data[ (data['ratio_ones'] >= alpha)]

cant = len(filtered_data['anho'].unique().tolist())
print(f'cantidad de años con ratio >= {alpha}: {cant}' )
filtered_data
# Out:
# cantidad de años con ratio >= 0.95: 0
# Empty DataFrame
# Columns: [file_name, anho, ratio_ones]
# Index: []

# %% [markdown]
# ## combined_indicators_area_country_anho

# %%
import pandas as pd
import holoviews as hv
import panel as pn

hv.extension('bokeh')

# Cargar el dataset
file_path = path_data / 'combined_indicators_area_country_anho.csv'
data = pd.read_csv(file_path)


# Crear un selector para file_name
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.Select(name='File Name', options=file_names)

# Función para actualizar el heatmap
@pn.depends(file_name_select.param.value)
def update_heatmap(file_name):
    filtered_data = data[data['file_name'] == file_name]
    heatmap = hv.HeatMap(filtered_data, kdims=['anho', 'country_code'], vdims=['ratio_ones'])
    heatmap = heatmap.opts(
        cmap='Viridis', 
        colorbar=True, 
        width=900, 
        height=600, 
        xlabel='Año', 
        ylabel='País', 
        tools=['hover'],
        xrotation=45,
        title=f'Ratio Ones por Año y País para {file_name}'
    )
    return heatmap

# Layout
layout = pn.Column(
    file_name_select,
    update_heatmap
)

# Mostrar el layout
layout.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e07df820-b9af-4c89-a265-40cd218801d4'>
#   <div id="e0662fcc-e17b-40e7-ac6c-d673b8f617ae" data-root-id="e07df820-b9af-4c89-a265-40cd218801d4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"53ae672a-8222-4ddb-9a17-78f2185693cd":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e07df820-b9af-4c89-a265-40cd218801d4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"6a95b558-d50f-4d9b-82df-2fdfec0fb23d","attributes":{"plot_id":"e07df820-b9af-4c89-a265-40cd218801d4","comm_id":"398605f9745c4925a5f86874e1aa910b","client_comm_id":"c276b185249047d9887d6848ff8e8238"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"53ae672a-8222-4ddb-9a17-78f2185693cd","roots":{"e07df820-b9af-4c89-a265-40cd218801d4":"e0662fcc-e17b-40e7-ac6c-d673b8f617ae"},"root_ids":["e07df820-b9af-4c89-a265-40cd218801d4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'38f9e8d3-e89a-4a79-9e31-5ea8054e6484': {'version…

# %% [markdown]
# ## combined_indicators_area_country_indicador

# %%
import pandas as pd
import holoviews as hv
import panel as pn

hv.extension('bokeh')

# Cargar el dataset
file_path = path_data / 'combined_indicators_area_country_indicador.csv'
data = pd.read_csv(file_path)


# Crear un selector para file_name
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.Select(name='File Name', options=file_names)

# Función para actualizar el heatmap
@pn.depends(file_name_select.param.value)
def update_heatmap(file_name):
    filtered_data = data[data['file_name'] == file_name]
    heatmap = hv.HeatMap(filtered_data, kdims=['country_code', 'indicator'], vdims=['ratio_ones'])
    heatmap = heatmap.opts(
        cmap='Viridis', 
        colorbar=True, 
        width=900, 
        height=600, 
        xlabel='País', 
        ylabel='Indicador', 
        tools=['hover'],
        xrotation=45,
        title=f'Ratio Ones por País e Indicador para {file_name}'
    )
    return heatmap

# Layout
layout = pn.Column(
    file_name_select,
    update_heatmap
)

# Mostrar el layout
layout.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0db22ccf-0ac2-4583-b306-1e7f000130e4'>
#   <div id="ef6a111b-c5dc-45dd-89d8-41ea1a5c8d0f" data-root-id="0db22ccf-0ac2-4583-b306-1e7f000130e4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2cd319f2-a81b-4de1-bc89-c9193564da66":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0db22ccf-0ac2-4583-b306-1e7f000130e4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1acf4ec6-d7f8-45d8-a272-f45b3dae6e6a","attributes":{"plot_id":"0db22ccf-0ac2-4583-b306-1e7f000130e4","comm_id":"0aa7771f875543a2815a7084bd932c52","client_comm_id":"9e9be47def564bfda5a66b7b42d51052"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"2cd319f2-a81b-4de1-bc89-c9193564da66","roots":{"0db22ccf-0ac2-4583-b306-1e7f000130e4":"ef6a111b-c5dc-45dd-89d8-41ea1a5c8d0f"},"root_ids":["0db22ccf-0ac2-4583-b306-1e7f000130e4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'f2f2dffa-4eff-4aa0-a0c1-bdb6cdc0b559': {'version…

# %%
alpha = 0.95
filtered_data = data[ (data['ratio_ones'] >= alpha)]

cant = len(filtered_data['indicator'].unique().tolist())
print(f'cantidad de indicadores con ratio >= {alpha}: {cant}' )
filtered_data
# Out:
# cantidad de indicadores con ratio >= 0.95: 401
#                               file_name country_code          indicator  \
# 3       Agriculture & Rural Development          ABW     AG.LND.AGRI.K2
# 4       Agriculture & Rural Development          ABW     AG.LND.AGRI.ZS
# 5       Agriculture & Rural Development          ABW     AG.LND.ARBL.HA
# 6       Agriculture & Rural Development          ABW  AG.LND.ARBL.HA.PC
# 7       Agriculture & Rural Development          ABW     AG.LND.ARBL.ZS
# ...                                 ...          ...                ...
# 454517                Urban Development          ZMB  SP.URB.TOTL.IN.ZS
# 454525                Urban Development          ZWE  EN.URB.LCTY.UR.ZS
# 454526                Urban Development          ZWE  EN.URB.MCTY.TL.ZS
# 454528                Urban Development          ZWE        SP.URB.GROW
# 454529                Urban Development          ZWE  SP.URB.TOTL.IN.ZS
#
#         ratio_ones
# 3         0.953125
# 4         0.953125
# 5         0.953125
# 6         0.953125
# 7         0.953125
# ...            ...
# 454517    0.984375
# 454525    1.000000
# 454526    1.000000
# 454528    0.968750
# 454529    0.984375
#
# [41805 rows x 4 columns]

# %% [markdown]
# ## combined_indicators_area_country

# %%
import pandas as pd
import holoviews as hv
import panel as pn

hv.extension('bokeh')

# Cargar el dataset
file_path = path_data / 'combined_indicators_area_country.csv'
data = pd.read_csv(file_path)

# Crear un selector para file_name
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.MultiSelect(name='File Names', options=file_names, size=10)

# Crear un selector para country_code
countries = list(data['country_code'].unique())
country_select = pn.widgets.MultiSelect(name='Countries', options=countries, size=10)

# Función para actualizar el heatmap
@pn.depends(file_name_select.param.value, country_select.param.value)
def update_heatmap(selected_file_names, selected_countries):
    filtered_data = data.copy()
    if selected_file_names:
        filtered_data = filtered_data[filtered_data['file_name'].isin(selected_file_names)]
    if selected_countries:
        filtered_data = filtered_data[filtered_data['country_code'].isin(selected_countries)]
    
    heatmap = hv.HeatMap(filtered_data, kdims=['file_name', 'country_code'], vdims=['ratio_ones'])
    heatmap = heatmap.opts(
        cmap='Viridis', 
        colorbar=True, 
        width=900, 
        height=600, 
        xlabel='File Name', 
        ylabel='País', 
        tools=['hover'],
        xrotation=45,
        title='Ratio Ones por File Name y País'
    )
    return heatmap

# Layout
layout = pn.Column(
    pn.Row(file_name_select, country_select),
    update_heatmap
)

# Mostrar el layout
layout.servable()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4d655948-3e09-4fc9-adf1-ae3db937d7ef'>
#   <div id="a81d0e5a-bd54-4ec1-8ede-9cec07ef88a3" data-root-id="4d655948-3e09-4fc9-adf1-ae3db937d7ef" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d7616575-93f8-4eec-8314-60dc4b9e1b96":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4d655948-3e09-4fc9-adf1-ae3db937d7ef"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"1e4daea6-4f41-45aa-9e3e-ecd8d18c38d7","attributes":{"plot_id":"4d655948-3e09-4fc9-adf1-ae3db937d7ef","comm_id":"cb7a78e64b054ccb9919b630d1256e98","client_comm_id":"1d116b2bf1414b26a23399c86f62c72d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"d7616575-93f8-4eec-8314-60dc4b9e1b96","roots":{"4d655948-3e09-4fc9-adf1-ae3db937d7ef":"a81d0e5a-bd54-4ec1-8ede-9cec07ef88a3"},"root_ids":["4d655948-3e09-4fc9-adf1-ae3db937d7ef"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'d4f41240-91fe-4603-b2f4-8cb3a3442dd1': {'version…

# %% [markdown]
# ## combined_indicators_area_indicator

# %%
# Cargar el dataset
file_path = path_data / 'combined_indicators_area_indicator.csv'
data = pd.read_csv(file_path)




# Crear un selector para file_name (área)
file_names = list(data['file_name'].unique())
file_name_select = pn.widgets.Select(name='File Name', options=file_names)

# Función para actualizar el gráfico de líneas/barras
@pn.depends(file_name_select.param.value)
def update_plot(file_name):
    filtered_data = data[data['file_name'] == file_name]
    
    # Crear el gráfico de líneas
    line_plot = hv.Curve(filtered_data, kdims=['indicator'], vdims=['ratio_ones'], label=file_name).opts(
        xlabel='Indicador', 
        ylabel='Ratio Ones', 
        title=f'Ratio Ones por Indicador para {file_name}',
        tools=['hover', 'pan', 'wheel_zoom', 'box_zoom', 'reset'],
        height=400, 
        width=900
    )

    # Crear el gráfico de barras
    bar_plot = hv.Bars(filtered_data, kdims=['indicator'], vdims=['ratio_ones'], label=file_name).opts(
        xlabel='Indicador', 
        ylabel='Ratio Ones', 
        title=f'Ratio Ones por Indicador para {file_name}',
        tools=['hover', 'pan', 'wheel_zoom', 'box_zoom', 'reset'],
        height=400, 
        width=900,
        xrotation=90
    )
    
    # Combinar ambos gráficos en una pestaña
    tabs = pn.Tabs(('Line Plot', line_plot), ('Bar Plot', bar_plot))
    return tabs

# Layout
layout = pn.Column(
    file_name_select,
    update_plot
)

# Mostrar el layout
layout.servable()
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'79763263-e192-4902-9064-603df1a7b058': {'version…

# %% [markdown]
# # Experimento 1: Baseline
#  Vamos a hacer un clustering sobre el indicador NY.GNP.PCAP.CN	(GNI per capita (current LCU))

# %% [markdown]
# ## Primero lo exploramos

# %%
import pandas as pd
from pathlib import Path

indicador = 'NY.GNP.PCAP.CN'
current_dir = Path.cwd()
print("Current directory:", current_dir)

# Ir un nivel arriba y luego a la carpeta 'data'
parent_dir = current_dir.parent

path_data = parent_dir / 'data'
file_name = 'combined_indicators_ALL.csv'
file_path = path_data / 'csv' /  f'{indicador}.csv'

GNI = pd.read_csv(file_path)

GNI
# Out:
# Current directory: /Users/miguelkiszkurno/Documents/TT1/03_eda
#                       Country Name Country Code   Año  NY.GNP.PCAP.CN
# 0                            Aruba          ABW  1960             NaN
# 1      Africa Eastern and Southern          AFE  1960             NaN
# 2                      Afghanistan          AFG  1960     2864.609521
# 3       Africa Western and Central          AFW  1960             NaN
# 4                           Angola          AGO  1960             NaN
# ...                            ...          ...   ...             ...
# 17019                       Kosovo          XKX  2023             NaN
# 17020                  Yemen, Rep.          YEM  2023             NaN
# 17021                 South Africa          ZAF  2023             NaN
# 17022                       Zambia          ZMB  2023             NaN
# 17023                     Zimbabwe          ZWE  2023             NaN
#
# [17024 rows x 4 columns]

# %%
excluir = [
    "AFE", "AFW", "ARB", "CEB", "CSS", "EAP", "EAR", "EAS",
    "ECA", "ECS", "EMU", "EUU", "FCS", "HIC", "HPC", "IBD",
    "IBT", "IDA", "IDB", "IDX", "LAC", "LCN", "LDC", "LIC",
    "LMC", "LMY", "LTE", "MEA", "MIC", "MNA", "NAC", "OED",
    "OSS", "PRE", "PSS", "PST", "SAS", "SSA", "SSF", "SST",
    "TEA", "TEC", "TLA", "TMN", "TSA", "TSS", "UMC", "WLD"
]

# Excluir los códigos de país del DataFrame
GNI = GNI[~GNI['Country Code'].isin(excluir)]

#Me quedo con los años hasta el maximo del que hay datos completos
GNI = GNI[GNI['Año'] <= 2022]

GNI
# Out:
#        Country Name Country Code   Año  NY.GNP.PCAP.CN
# 0             Aruba          ABW  1960             NaN
# 2       Afghanistan          AFG  1960     2864.609521
# 4            Angola          AGO  1960             NaN
# 5           Albania          ALB  1960             NaN
# 6           Andorra          AND  1960             NaN
# ...             ...          ...   ...             ...
# 16753        Kosovo          XKX  2022     5137.210835
# 16754   Yemen, Rep.          YEM  2022             NaN
# 16755  South Africa          ZAF  2022   108361.095628
# 16756        Zambia          ZMB  2022    24676.392238
# 16757      Zimbabwe          ZWE  2022   741359.064322
#
# [13734 rows x 4 columns]

# %%
file_name = 'metadata_countries.csv'
file_path = path_data /  file_name

paises = pd.read_csv(file_path)

# Excluir los códigos de país del DataFrame
paises = paises[~paises['country_code'].isin(excluir)]
paises
# Out:
#     country_code                      region         income_group  \
# 0            ABW   Latin America & Caribbean          High income
# 2            AFG                  South Asia           Low income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 5            ALB       Europe & Central Asia  Upper middle income
# 6            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                          special_notes  country_name
# 0                                                  NaN         Aruba
# 2    The reporting period for national accounts dat...   Afghanistan
# 4    The World Bank systematically assesses the app...        Angola
# 5                                                  NaN       Albania
# 6                                                  NaN       Andorra
# ..                                                 ...           ...
# 260                                                NaN        Kosovo
# 261  The World Bank systematically assesses the app...   Yemen, Rep.
# 262  Fiscal year end: March 31; reporting period fo...  South Africa
# 263  National accounts data were rebased to reflect...        Zambia
# 264  National Accounts data are reported in Zimbabw...      Zimbabwe
#
# [217 rows x 5 columns]

# %%
merged_data = pd.merge(GNI, paises, left_on='Country Code', right_on='country_code', how='inner')
merged_data
# Out:
#        Country Name Country Code   Año  NY.GNP.PCAP.CN country_code  \
# 0             Aruba          ABW  1960             NaN          ABW
# 1       Afghanistan          AFG  1960     2864.609521          AFG
# 2            Angola          AGO  1960             NaN          AGO
# 3           Albania          ALB  1960             NaN          ALB
# 4           Andorra          AND  1960             NaN          AND
# ...             ...          ...   ...             ...          ...
# 13666        Kosovo          XKX  2022     5137.210835          XKX
# 13667   Yemen, Rep.          YEM  2022             NaN          YEM
# 13668  South Africa          ZAF  2022   108361.095628          ZAF
# 13669        Zambia          ZMB  2022    24676.392238          ZMB
# 13670      Zimbabwe          ZWE  2022   741359.064322          ZWE
#
#                            region         income_group  \
# 0       Latin America & Caribbean          High income
# 1                      South Asia           Low income
# 2              Sub-Saharan Africa  Lower middle income
# 3           Europe & Central Asia  Upper middle income
# 4           Europe & Central Asia          High income
# ...                           ...                  ...
# 13666       Europe & Central Asia  Upper middle income
# 13667  Middle East & North Africa           Low income
# 13668          Sub-Saharan Africa  Upper middle income
# 13669          Sub-Saharan Africa  Lower middle income
# 13670          Sub-Saharan Africa  Lower middle income
#
#                                            special_notes  country_name
# 0                                                    NaN         Aruba
# 1      The reporting period for national accounts dat...   Afghanistan
# 2      The World Bank systematically assesses the app...        Angola
# 3                                                    NaN       Albania
# 4                                                    NaN       Andorra
# ...                                                  ...           ...
# 13666                                                NaN        Kosovo
# 13667  The World Bank systematically assesses the app...   Yemen, Rep.
# 13668  Fiscal year end: March 31; reporting period fo...  South Africa
# 13669  National accounts data were rebased to reflect...        Zambia
# 13670  National Accounts data are reported in Zimbabw...      Zimbabwe
#
# [13671 rows x 9 columns]

# %%
merged_data[['country_code', 'country_name', 'Año', 'region', 'income_group', 'NY.GNP.PCAP.CN']].to_csv(path_data / 'GNI.csv', index=False)

# %%
import pandas as pd
import holoviews as hv
from holoviews import opts
from bokeh.sampledata.iris import flowers
import panel as pn


hv.extension('bokeh')

data = merged_data



# Crear un selector para los países
countries = list(data['country_name'].unique())
country_select = pn.widgets.Select(name='Country', options=countries)

# Función para actualizar el gráfico de líneas
@pn.depends(country_select.param.value)
def update_plot(country):
    country_data = data[data['country_name'] == country]
    if country_data.empty:
        return hv.Curve([], 'Año', 'NY.GNP.PCAP.CN').opts(title="No data available for the selected country")
    curve = hv.Curve(country_data, 'Año', 'NY.GNP.PCAP.CN').opts(
        title=f'GNI per Capita for {country}',
        xlabel='Year',
        ylabel='GNI per Capita',
        width=800,
        height=400
    )
    return curve

# Layout
layout = pn.Column(
    country_select,
    update_plot
)

# Mostrar el layout
layout.servable()
layout.show() # Esto es para mostrarlo directamente en el notebook
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3d9f224e-b1d3-4222-97cd-a34870cc8e5a'>
#   <div id="bafb0551-1107-42de-84af-f8b95d92761e" data-root-id="3d9f224e-b1d3-4222-97cd-a34870cc8e5a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4e569f43-49fc-4df2-ab63-9d41721f2405":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3d9f224e-b1d3-4222-97cd-a34870cc8e5a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"41c688c8-5464-43a8-b86d-d4e90d6f4536","attributes":{"plot_id":"3d9f224e-b1d3-4222-97cd-a34870cc8e5a","comm_id":"604cd588424f4f7f9e5b0aac9d2c160e","client_comm_id":"34d18cd6c24e4717b31575673ca002e7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"4e569f43-49fc-4df2-ab63-9d41721f2405","roots":{"3d9f224e-b1d3-4222-97cd-a34870cc8e5a":"bafb0551-1107-42de-84af-f8b95d92761e"},"root_ids":["3d9f224e-b1d3-4222-97cd-a34870cc8e5a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# Launching server at http://localhost:50398
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='17b6e24d-6586-4eb3-a42c-5fa062843587', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='1aeeca5a-dc24-4a5c-b473-5dd1ea5a5783', ...)

# %% [markdown]
# ## Clustering 1.1: Hacemos el primer clustering
# Como vienen los datos con KMeans

# %% [markdown]
# Indicadores involucrados:
# - SP.POP.TOTL: https://data.worldbank.org/indicator/SP.POP.TOTL?view=chart
# - NY.GNP.MKTP.CD

# %% [markdown]
# ### Obtener los datos

# %%
import pandas as pd

pop_code = 'SP.POP.TOTL'
gni_code = 'NY.GNP.MKTP.CD'
anho_cluster = 2022

# Cargar los datasets
gni_path = path_data / 'csv' /  f'{gni_code}.csv'
pop_path = path_data / 'csv' /  f'{pop_code}.csv'
metadata_path =  path_data / 'metadata_countries.csv'

gni_data = pd.read_csv(gni_path)
pop_data = pd.read_csv(pop_path)
metadata = pd.read_csv(metadata_path)


# Renombrar las columnas para que sean consistentes
gni_data.columns = ['Country Name', 'Country Code', 'Year', 'GNI']
pop_data.columns = ['Country Name', 'Country Code', 'Year', 'Population']
metadata.columns = ['Country Code', 'Region', 'Income Group', 'special_notes', 'Country Name']

# Unificar los datasets por 'Country Name', 'Country Code', y 'Year'
merged_data = pd.merge(gni_data, pop_data, on=['Country Name', 'Country Code', 'Year'])
merged_data = pd.merge(merged_data, metadata, on=['Country Name', 'Country Code'])
merged_data.head()
# Out:
#                   Country Name Country Code  Year           GNI   Population  \
# 0                        Aruba          ABW  1960           NaN      54608.0
# 1  Africa Eastern and Southern          AFE  1960  1.713262e+10  130692579.0
# 2                  Afghanistan          AFG  1960  5.488888e+08    8622466.0
# 3   Africa Western and Central          AFW  1960           NaN   97256290.0
# 4                       Angola          AGO  1960           NaN    5357195.0
#
#                       Region         Income Group  \
# 0  Latin America & Caribbean          High income
# 1                        NaN                  NaN
# 2                 South Asia           Low income
# 3                        NaN                  NaN
# 4         Sub-Saharan Africa  Lower middle income
#
#                                        special_notes
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...

# %% [markdown]
# ### Filtrar por el año

# %%
# Filtrar los datos para el año 2022
data_2022 = merged_data[merged_data['Year'] == anho_cluster]
data_2022['gni_index'] = data_2022['GNI'] / data_2022['Population']
data_2022.head()
# Out:
# /var/folders/ks/xzv0k5v114g7mcm7_rvn57kc0000gn/T/ipykernel_36255/3750701640.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2022['gni_index'] = data_2022['GNI'] / data_2022['Population']
#                       Country Name Country Code  Year           GNI  \
# 15872                        Aruba          ABW  2022  3.421948e+09
# 15873  Africa Eastern and Southern          AFE  2022  1.153983e+12
# 15874                  Afghanistan          AFG  2022           NaN
# 15875   Africa Western and Central          AFW  2022  8.467289e+11
# 15876                       Angola          AGO  2022  9.873763e+10
#
#         Population                     Region         Income Group  \
# 15872     106445.0  Latin America & Caribbean          High income
# 15873  720859132.0                        NaN                  NaN
# 15874   41128771.0                 South Asia           Low income
# 15875  490330870.0                        NaN                  NaN
# 15876   35588987.0         Sub-Saharan Africa  Lower middle income
#
#                                            special_notes     gni_index
# 15872                                                NaN  32147.572330
# 15873  26 countries, stretching from the Red Sea in t...   1600.843665
# 15874  The reporting period for national accounts dat...           NaN
# 15875  22 countries, stretching from the westernmost ...   1726.852196
# 15876  The World Bank systematically assesses the app...   2774.387254

# %% [markdown]
# ### Eliminar las regiones

# %%
data_2022 = data_2022[~data_2022['Country Code'].isin(excluir)]

# %%
import matplotlib.pyplot as plt

# Boxplots en una fila
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Boxplot para GNI
axes[0].boxplot(data_2022['GNI'].dropna())
axes[0].set_title('Boxplot of GNI for 2022')
axes[0].set_ylabel('GNI')

# Boxplot para Population
axes[1].boxplot(data_2022['Population'].dropna())
axes[1].set_title('Boxplot of Population for 2022')
axes[1].set_ylabel('Population')

# Boxplot para GNI per Capita
axes[2].boxplot(data_2022['gni_index'].dropna())
axes[2].set_title('Boxplot of GNI per Capita for 2022')
axes[2].set_ylabel('GNI per Capita')

plt.tight_layout()
plt.show()

# %%
# Visualización de la distribución del GNI per Capita
plt.figure(figsize=(12, 8))
plt.hist(data_2022['gni_index'], bins=50, edgecolor='k', alpha=0.7)
plt.xlabel('GNI per Capita')
plt.ylabel('Number of Countries')
plt.title('Distribution of GNI per Capita for 2022')
plt.axvline(x=1135, color='r', linestyle='--', label='Low income / Lower middle income')
plt.axvline(x=4465, color='y', linestyle='--', label='Lower middle income / Upper middle income')
plt.axvline(x=13845, color='g', linestyle='--', label='Upper middle income / High income')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.experimental import enable_iterative_imputer  # Necesario para habilitar IterativeImputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import confusion_matrix, adjusted_rand_score, normalized_mutual_info_score, homogeneity_completeness_v_measure
import seaborn as sns

data_2022['log_gni_index'] = np.log1p(data_2022['gni_index'])  # np.log1p para log(1 + x), que maneja mejor valores pequeños
# Visualización de la distribución antes y después de la transformación logarítmica
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Distribución original
axes[0].hist(data_2022['gni_index'], bins=50, edgecolor='k', alpha=0.7)
axes[0].set_xlabel('GNI per Capita')
axes[0].set_ylabel('Number of Countries')
axes[0].set_title('Distribution of GNI per Capita for 2022')
axes[0].axvline(x=1135, color='r', linestyle='--', label='Low income / Lower middle income')
axes[0].axvline(x=4465, color='y', linestyle='--', label='Lower middle income / Upper middle income')
axes[0].axvline(x=13845, color='g', linestyle='--', label='Upper middle income / High income')
axes[0].legend()

# Distribución transformada
axes[1].hist(data_2022['log_gni_index'], bins=50, edgecolor='k', alpha=0.7)
axes[1].set_xlabel('Log of GNI per Capita')
axes[1].set_ylabel('Number of Countries')
axes[1].set_title('Distribution of Log of GNI per Capita for 2022')
axes[1].axvline(x=np.log1p(1135), color='r', linestyle='--', label='Low income / Lower middle income')
axes[1].axvline(x=np.log1p(4465), color='y', linestyle='--', label='Lower middle income / Upper middle income')
axes[1].axvline(x=np.log1p(13845), color='g', linestyle='--', label='Upper middle income / High income')
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Preparar los datos para clustering

# %%
data_2022 = data_2022.dropna(subset=['gni_index'])
data_2022
# Out:
#                Country Name Country Code  Year           GNI  Population  \
# 15872                 Aruba          ABW  2022  3.421948e+09    106445.0
# 15876                Angola          AGO  2022  9.873763e+10  35588987.0
# 15877               Albania          ALB  2022  1.856938e+10   2777689.0
# 15880  United Arab Emirates          ARE  2022  5.045748e+11   9441129.0
# 15881             Argentina          ARG  2022  6.191449e+11  46234830.0
# ...                     ...          ...   ...           ...         ...
# 16122                 Samoa          WSM  2022  8.112463e+08    222382.0
# 16123                Kosovo          XKX  2022  9.531103e+09   1761985.0
# 16125          South Africa          ZAF  2022  3.968101e+11  59893885.0
# 16126                Zambia          ZMB  2022  2.916376e+10  20017675.0
# 16127              Zimbabwe          ZWE  2022  2.672808e+10  16320537.0
#
#                            Region         Income Group  \
# 15872   Latin America & Caribbean          High income
# 15876          Sub-Saharan Africa  Lower middle income
# 15877       Europe & Central Asia  Upper middle income
# 15880  Middle East & North Africa          High income
# 15881   Latin America & Caribbean  Upper middle income
# ...                           ...                  ...
# 16122         East Asia & Pacific  Lower middle income
# 16123       Europe & Central Asia  Upper middle income
# 16125          Sub-Saharan Africa  Upper middle income
# 16126          Sub-Saharan Africa  Lower middle income
# 16127          Sub-Saharan Africa  Lower middle income
#
#                                            special_notes     gni_index  \
# 15872                                                NaN  32147.572330
# 15876  The World Bank systematically assesses the app...   2774.387254
# 15877                                                NaN   6685.188771
# 15880                                                NaN  53444.327682
# 15881  The World Bank systematically assesses the app...  13391.308920
# ...                                                  ...           ...
# 16122  The reporting period for national accounts dat...   3647.985505
# 16123                                                NaN   5409.298552
# 16125  Fiscal year end: March 31; reporting period fo...   6625.218240
# 16126  National accounts data were rebased to reflect...   1456.900681
# 16127  National Accounts data are reported in Zimbabw...   1637.696163
#
#        log_gni_index  Cluster       Cluster Mapped
# 15872      10.378123        0  Upper middle income
# 15876       7.928546        3  Lower middle income
# 15877       8.807799        3  Lower middle income
# 15880      10.886414        2           Low income
# 15881       9.502436        3  Lower middle income
# ...              ...      ...                  ...
# 16122       8.202204        3  Lower middle income
# 16123       8.596060        3  Lower middle income
# 16125       8.798790        3  Lower middle income
# 16126       7.284753        3  Lower middle income
# 16127       7.401656        3  Lower middle income
#
# [184 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Escalar los datos de gni_index
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_2022[['gni_index']])

# Aplicar k-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
data_2022['Cluster'] = kmeans.fit_predict(data_scaled)

# %% [markdown]
# ### Visualizar los clusters

# %%
#print (data_2022[data_2022['Cluster']==0]['Country Name'].tolist())

# %%
import matplotlib.pyplot as plt

# Mapeo de los números de cluster a las categorías de ingreso
cluster_mapping = {2: 'Upper middle income', 1: 'High income',  3: 'Low income', 0: 'Lower middle income' }
data_2022['Cluster Mapped'] = data_2022['Cluster'].map(cluster_mapping)
data_2022
data_2022.to_csv(path_data / 'clusters.csv')

# Definir colores personalizados para cada cluster
colors = {1: 'green', 2: 'yellow', 0: 'orange', 3: 'red'}

# Asignar colores a cada punto del scatter plot
cluster_colors = data_2022['Cluster'].map(colors)


# Visualización de los clusters
plt.figure(figsize=(12, 8))
plt.scatter(data_2022['Country Name'], data_2022['gni_index'], c=cluster_colors)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('GNI per Capita')
plt.title('K-means Clustering of Countries by GNI per Capita for 2022')
plt.axhline(y=1135, color='r', linestyle='--', label='Low income / Lower middle income')
plt.axhline(y=4465, color='y', linestyle='--', label='Lower middle income / Upper middle income')
plt.axhline(y=13845, color='g', linestyle='--', label='Upper middle income / High income')

# Agregar una leyenda personalizada usando cluster_mapping
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=colors[cluster], markersize=10, label=label)
                   for cluster, label in cluster_mapping.items()]

plt.legend(handles=legend_handles, title='Cluster')
plt.show()

# %%
data_2022
# Out:
#                Country Name Country Code  Year           GNI  Population  \
# 15872                 Aruba          ABW  2022  3.421948e+09    106445.0
# 15876                Angola          AGO  2022  9.873763e+10  35588987.0
# 15877               Albania          ALB  2022  1.856938e+10   2777689.0
# 15880  United Arab Emirates          ARE  2022  5.045748e+11   9441129.0
# 15881             Argentina          ARG  2022  6.191449e+11  46234830.0
# ...                     ...          ...   ...           ...         ...
# 16122                 Samoa          WSM  2022  8.112463e+08    222382.0
# 16123                Kosovo          XKX  2022  9.531103e+09   1761985.0
# 16125          South Africa          ZAF  2022  3.968101e+11  59893885.0
# 16126                Zambia          ZMB  2022  2.916376e+10  20017675.0
# 16127              Zimbabwe          ZWE  2022  2.672808e+10  16320537.0
#
#                            Region         Income Group  \
# 15872   Latin America & Caribbean          High income
# 15876          Sub-Saharan Africa  Lower middle income
# 15877       Europe & Central Asia  Upper middle income
# 15880  Middle East & North Africa          High income
# 15881   Latin America & Caribbean  Upper middle income
# ...                           ...                  ...
# 16122         East Asia & Pacific  Lower middle income
# 16123       Europe & Central Asia  Upper middle income
# 16125          Sub-Saharan Africa  Upper middle income
# 16126          Sub-Saharan Africa  Lower middle income
# 16127          Sub-Saharan Africa  Lower middle income
#
#                                            special_notes     gni_index  \
# 15872                                                NaN  32147.572330
# 15876  The World Bank systematically assesses the app...   2774.387254
# 15877                                                NaN   6685.188771
# 15880                                                NaN  53444.327682
# 15881  The World Bank systematically assesses the app...  13391.308920
# ...                                                  ...           ...
# 16122  The reporting period for national accounts dat...   3647.985505
# 16123                                                NaN   5409.298552
# 16125  Fiscal year end: March 31; reporting period fo...   6625.218240
# 16126  National accounts data were rebased to reflect...   1456.900681
# 16127  National Accounts data are reported in Zimbabw...   1637.696163
#
#        log_gni_index  Cluster       Cluster Mapped  Cluster_Original  \
# 15872      10.378123        2  Upper middle income                 0
# 15876       7.928546        3           Low income                 3
# 15877       8.807799        3           Low income                 3
# 15880      10.886414        2  Upper middle income                 2
# 15881       9.502436        0  Lower middle income                 3
# ...              ...      ...                  ...               ...
# 16122       8.202204        3           Low income                 3
# 16123       8.596060        3           Low income                 3
# 16125       8.798790        3           Low income                 3
# 16126       7.284753        1          High income                 3
# 16127       7.401656        1          High income                 3
#
#        Cluster_Log Cluster_Original_Mapped   Cluster_Log_Mapped
# 15872            2     Lower middle income  Upper middle income
# 15876            3              Low income           Low income
# 15877            3              Low income           Low income
# 15880            2     Upper middle income  Upper middle income
# 15881            0              Low income  Lower middle income
# ...            ...                     ...                  ...
# 16122            3              Low income           Low income
# 16123            3              Low income           Low income
# 16125            3              Low income           Low income
# 16126            1              Low income          High income
# 16127            1              Low income          High income
#
# [184 rows x 16 columns]

# %% [markdown]
# ### Matriz de Confusion

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns



# Comparar los clusters con las categorías de ingresos
comparison = data_2022[['Country Name', 'gni_index', 'Cluster Mapped', 'Income Group']]

# Crear la matriz de confusión
conf_matrix = confusion_matrix(data_2022['Income Group'], data_2022['Cluster Mapped'], labels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'], yticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
plt.xlabel('Predicted Cluster')
plt.ylabel('True Income Group')
plt.title('Confusion Matrix for Clusters vs Income Groups')
plt.show()

# Mostrar la tabla de comparación
comparison.head(20)
# Out:
#                  Country Name     gni_index       Cluster Mapped  \
# 15872                   Aruba  32147.572330  Lower middle income
# 15876                  Angola   2774.387254           Low income
# 15877                 Albania   6685.188771           Low income
# 15880    United Arab Emirates  53444.327682  Upper middle income
# 15881               Argentina  13391.308920           Low income
# 15882                 Armenia   6712.841725           Low income
# 15884     Antigua and Barbuda  19300.632288  Lower middle income
# 15885               Australia  62640.097214  Upper middle income
# 15886                 Austria  52050.890378  Upper middle income
# 15887              Azerbaijan   7240.978317           Low income
# 15888                 Burundi    260.110138           Low income
# 15889                 Belgium  50698.124194  Upper middle income
# 15890                   Benin   1291.791985           Low income
# 15891            Burkina Faso    795.177482           Low income
# 15892              Bangladesh   2794.807092           Low income
# 15893                Bulgaria  13517.371240           Low income
# 15894                 Bahrain  28813.576297  Lower middle income
# 15895            Bahamas, The  29826.993249  Lower middle income
# 15896  Bosnia and Herzegovina   7511.643262           Low income
# 15897                 Belarus   7593.951146           Low income
#
#               Income Group
# 15872          High income
# 15876  Lower middle income
# 15877  Upper middle income
# 15880          High income
# 15881  Upper middle income
# 15882  Upper middle income
# 15884          High income
# 15885          High income
# 15886          High income
# 15887  Upper middle income
# 15888           Low income
# 15889          High income
# 15890  Lower middle income
# 15891           Low income
# 15892  Lower middle income
# 15893  Upper middle income
# 15894          High income
# 15895          High income
# 15896  Upper middle income
# 15897  Upper middle income

# %% [markdown]
# ## Clustering 1.2: Acplicando transformacion logaritmica

# %%
# Escalar los datos transformados usando StandardScaler
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_2022[['log_gni_index']])

# Aplicar k-means clustering
kmeans_log = KMeans(n_clusters=4, random_state=42)
data_2022['Cluster'] = kmeans_log.fit_predict(data_scaled)

# Mapeo de los números de cluster a las categorías de ingreso
cluster_mapping = {1: 'Low income', 3: 'Lower middle income', 0: 'Upper middle income', 2: 'High income'}
data_2022['Cluster Mapped'] = data_2022['Cluster'].map(cluster_mapping)
data_2022.to_csv(path_data / 'clusters_log.csv')

# Definir colores personalizados para cada cluster
colors = {2: 'green', 0: 'yellow', 3: 'orange', 1: 'red'}

# Asignar colores a cada punto del scatter plot
cluster_colors = data_2022['Cluster'].map(colors)



# Comparar los clusters con las categorías de ingresos
comparison = data_2022[['Country Name', 'log_gni_index', 'Cluster Mapped', 'Income Group']]

# Crear la matriz de confusión
conf_matrix = confusion_matrix(data_2022['Income Group'], data_2022['Cluster Mapped'], labels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])

# Visualizar la matriz de confusión
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'], yticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
plt.xlabel('Predicted Cluster')
plt.ylabel('True Income Group')
plt.title('Confusion Matrix for Clusters vs Income Groups')
plt.show()

# Visualización de los clusters con líneas divisorias en escala logarítmica
plt.figure(figsize=(12, 8))
plt.scatter(data_2022['Country Name'], data_2022['log_gni_index'], c=cluster_colors)
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Log of GNI per Capita')
plt.title('K-means Clustering of Countries by Log of GNI per Capita for 2022')
plt.axhline(y=np.log1p(1135), color='r', linestyle='--', label='Low income / Lower middle income')
plt.axhline(y=np.log1p(4465), color='b', linestyle='--', label='Lower middle income / Upper middle income')
plt.axhline(y=np.log1p(13845), color='g', linestyle='--', label='Upper middle income / High income')
plt.legend()
plt.colorbar(label='Cluster')
plt.show()

# Mostrar la tabla de comparación
comparison.head(20)
# Out:
#                  Country Name  log_gni_index       Cluster Mapped  \
# 15872                   Aruba      10.378123          High income
# 15876                  Angola       7.928546  Lower middle income
# 15877                 Albania       8.807799  Lower middle income
# 15880    United Arab Emirates      10.886414          High income
# 15881               Argentina       9.502436  Upper middle income
# 15882                 Armenia       8.811927  Lower middle income
# 15884     Antigua and Barbuda       9.867945  Upper middle income
# 15885               Australia      11.045177          High income
# 15886                 Austria      10.859996          High income
# 15887              Azerbaijan       8.887650  Lower middle income
# 15888                 Burundi       5.564942           Low income
# 15889                 Belgium      10.833664          High income
# 15890                   Benin       7.164559           Low income
# 15891            Burkina Faso       6.679822           Low income
# 15892              Bangladesh       7.935876  Lower middle income
# 15893                Bulgaria       9.511805  Upper middle income
# 15894                 Bahrain      10.268637  Upper middle income
# 15895            Bahamas, The      10.303203  Upper middle income
# 15896  Bosnia and Herzegovina       8.924343  Lower middle income
# 15897                 Belarus       8.935239  Lower middle income
#
#               Income Group
# 15872          High income
# 15876  Lower middle income
# 15877  Upper middle income
# 15880          High income
# 15881  Upper middle income
# 15882  Upper middle income
# 15884          High income
# 15885          High income
# 15886          High income
# 15887  Upper middle income
# 15888           Low income
# 15889          High income
# 15890  Lower middle income
# 15891           Low income
# 15892  Lower middle income
# 15893  Upper middle income
# 15894          High income
# 15895          High income
# 15896  Upper middle income
# 15897  Upper middle income

# %% [markdown]
# ## Comparamos los dos clusterings

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, adjusted_rand_score, normalized_mutual_info_score, homogeneity_completeness_v_measure
import seaborn as sns

# Aplicar transformación logarítmica a gni_index
data_2022['log_gni_index'] = np.log1p(data_2022['gni_index'])  # np.log1p para log(1 + x), que maneja mejor valores pequeños

# Escalar los datos originales usando StandardScaler
scaler = StandardScaler()
data_scaled_original = scaler.fit_transform(data_2022[['gni_index']])

# Escalar los datos transformados usando StandardScaler
data_scaled_log = scaler.fit_transform(data_2022[['log_gni_index']])

# Aplicar k-means clustering a los datos originales
kmeans_original = KMeans(n_clusters=4, random_state=42)
data_2022['Cluster_Original'] = kmeans_original.fit_predict(data_scaled_original)

# Aplicar k-means clustering a los datos transformados
kmeans_log = KMeans(n_clusters=4, random_state=42)
data_2022['Cluster_Log'] = kmeans_log.fit_predict(data_scaled_log)

# Mapeo de los números de cluster a las categorías de ingreso
cluster_mapping = {3: 'Low income', 0: 'Lower middle income', 2: 'Upper middle income', 1: 'High income'}
data_2022['Cluster_Original_Mapped'] = data_2022['Cluster_Original'].map(cluster_mapping)
data_2022['Cluster_Log_Mapped'] = data_2022['Cluster_Log'].map(cluster_mapping)

# Comparar los clusters con las categorías de ingresos
comparison_original = data_2022[['Country Name', 'gni_index', 'Cluster_Original_Mapped', 'Income Group']]
comparison_log = data_2022[['Country Name', 'log_gni_index', 'Cluster_Log_Mapped', 'Income Group']]

# Crear las matrices de confusión
conf_matrix_original = confusion_matrix(data_2022['Income Group'], data_2022['Cluster_Original_Mapped'], labels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
conf_matrix_log = confusion_matrix(data_2022['Income Group'], data_2022['Cluster_Log_Mapped'], labels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])

# Visualizar las matrices de confusión
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_original, annot=True, fmt='d', cmap='Blues', xticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'], yticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
plt.xlabel('Predicted Cluster')
plt.ylabel('True Income Group')
plt.title('Confusion Matrix for Clusters vs Income Groups (Original)')
plt.show()

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_log, annot=True, fmt='d', cmap='Blues', xticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'], yticklabels=['Low income', 'Lower middle income', 'Upper middle income', 'High income'])
plt.xlabel('Predicted Cluster')
plt.ylabel('True Income Group')
plt.title('Confusion Matrix for Clusters vs Income Groups (Log Transformed)')
plt.show()

# Comparar las métricas de evaluación
true_labels = data_2022['Income Group']

ari_original = adjusted_rand_score(true_labels, data_2022['Cluster_Original_Mapped'])
nmi_original = normalized_mutual_info_score(true_labels, data_2022['Cluster_Original_Mapped'])
homogeneity_original, completeness_original, v_measure_original = homogeneity_completeness_v_measure(true_labels, data_2022['Cluster_Original_Mapped'])

ari_log = adjusted_rand_score(true_labels, data_2022['Cluster_Log_Mapped'])
nmi_log = normalized_mutual_info_score(true_labels, data_2022['Cluster_Log_Mapped'])
homogeneity_log, completeness_log, v_measure_log = homogeneity_completeness_v_measure(true_labels, data_2022['Cluster_Log_Mapped'])

print(f'Original Clustering Metrics:')
print(f'ARI: {ari_original:.4f}')
print(f'NMI: {nmi_original:.4f}')
print(f'Homogeneity: {homogeneity_original:.4f}')
print(f'Completeness: {completeness_original:.4f}')
print(f'V-Measure: {v_measure_original:.4f}')

print(f'\nLog Transformed Clustering Metrics:')
print(f'ARI: {ari_log:.4f}')
print(f'NMI: {nmi_log:.4f}')
print(f'Homogeneity: {homogeneity_log:.4f}')
print(f'Completeness: {completeness_log:.4f}')
print(f'V-Measure: {v_measure_log:.4f}')

# Mostrar las tablas de comparación
comparison_original.head(20)
comparison_log.head(20)
# Out:
# Original Clustering Metrics:
# ARI: 0.2892
# NMI: 0.5172
# Homogeneity: 0.4515
# Completeness: 0.6053
# V-Measure: 0.5172
#
# Log Transformed Clustering Metrics:
# ARI: 0.4007
# NMI: 0.5798
# Homogeneity: 0.5896
# Completeness: 0.5703
# V-Measure: 0.5798
#                  Country Name  log_gni_index   Cluster_Log_Mapped  \
# 15872                   Aruba      10.378123  Upper middle income
# 15876                  Angola       7.928546           Low income
# 15877                 Albania       8.807799           Low income
# 15880    United Arab Emirates      10.886414  Upper middle income
# 15881               Argentina       9.502436  Lower middle income
# 15882                 Armenia       8.811927           Low income
# 15884     Antigua and Barbuda       9.867945  Lower middle income
# 15885               Australia      11.045177  Upper middle income
# 15886                 Austria      10.859996  Upper middle income
# 15887              Azerbaijan       8.887650           Low income
# 15888                 Burundi       5.564942          High income
# 15889                 Belgium      10.833664  Upper middle income
# 15890                   Benin       7.164559          High income
# 15891            Burkina Faso       6.679822          High income
# 15892              Bangladesh       7.935876           Low income
# 15893                Bulgaria       9.511805  Lower middle income
# 15894                 Bahrain      10.268637  Lower middle income
# 15895            Bahamas, The      10.303203  Lower middle income
# 15896  Bosnia and Herzegovina       8.924343           Low income
# 15897                 Belarus       8.935239           Low income
#
#               Income Group
# 15872          High income
# 15876  Lower middle income
# 15877  Upper middle income
# 15880          High income
# 15881  Upper middle income
# 15882  Upper middle income
# 15884          High income
# 15885          High income
# 15886          High income
# 15887  Upper middle income
# 15888           Low income
# 15889          High income
# 15890  Lower middle income
# 15891           Low income
# 15892  Lower middle income
# 15893  Upper middle income
# 15894          High income
# 15895          High income
# 15896  Upper middle income
# 15897  Upper middle income

# %% [markdown]
# ### Conclusiones (segun Chat GPT)

# %% [markdown]
# Las métricas de evaluación que has obtenido se interpretan de la siguiente manera:
#
# Adjusted Rand Index (ARI): Mide la similitud entre dos agrupamientos, ajustando por la posibilidad de agrupamientos aleatorios. Los valores oscilan entre -1 y 1, donde 1 indica una coincidencia perfecta, 0 indica una coincidencia no mejor que el azar y valores negativos indican coincidencias peores que el azar.
#
# Normalized Mutual Information (NMI): Mide la cantidad de información compartida entre dos agrupamientos. Los valores oscilan entre 0 y 1, donde 1 indica una coincidencia perfecta y 0 indica que no hay información compartida.
#
# Homogeneity: Indica que todos los puntos de cada cluster pertenecen a la misma clase verdadera. Los valores oscilan entre 0 y 1, donde 1 indica homogeneidad perfecta.
#
# Completeness: Indica que todos los puntos de una clase verdadera están asignados al mismo cluster. Los valores oscilan entre 0 y 1, donde 1 indica completitud perfecta.
#
# V-Measure: Es la media armónica de la homogeneidad y la completitud. Los valores oscilan entre 0 y 1, donde 1 indica una coincidencia perfecta.
#
# Interpretación de los resultados:
# Original Clustering Metrics:
# ARI: 0.2892: Hay cierta similitud entre los agrupamientos y las categorías verdaderas, pero no es muy alta.
# NMI: 0.5172: Algo más de la mitad de la información es compartida entre los agrupamientos y las categorías verdaderas.
# Homogeneity: 0.4515: Los clusters son moderadamente homogéneos.
# Completeness: 0.6053: La mayoría de los puntos de una clase verdadera están asignados al mismo cluster.
# V-Measure: 0.5172: La medida compuesta muestra una correspondencia moderada entre los clusters y las categorías verdaderas.
# Log Transformed Clustering Metrics:
# ARI: 0.4007: La similitud entre los agrupamientos y las categorías verdaderas es mayor que con los datos originales.
# NMI: 0.5798: Hay una mayor cantidad de información compartida entre los agrupamientos y las categorías verdaderas en comparación con los datos originales.
# Homogeneity: 0.5896: Los clusters son más homogéneos que con los datos originales.
# Completeness: 0.5703: La completitud es ligeramente menor que con los datos originales.
# V-Measure: 0.5798: La medida compuesta muestra una mejor correspondencia entre los clusters y las categorías verdaderas en comparación con los datos originales.
# Conclusiones:
# Mejora general con la transformación logarítmica:
#
# La mayoría de las métricas (ARI, NMI, Homogeneity, V-Measure) mejoran con la transformación logarítmica, lo que sugiere que la transformación logarítmica ayuda a que los clusters se alineen mejor con las categorías de ingresos verdaderas.
# La única métrica que disminuye ligeramente es la completitud, pero la diferencia no es significativa.
# Mayor similitud con categorías verdaderas:
#
# La mayor ARI y NMI con los datos transformados indican una mayor similitud y mayor cantidad de información compartida entre los clusters y las categorías verdaderas.
# Mejor balance entre homogeneidad y completitud:
#
# La mayor V-Measure con los datos transformados indica un mejor balance entre homogeneidad y completitud en comparación con los datos originales.
# En resumen, los resultados sugieren que la transformación logarítmica mejora la calidad del clustering, haciendo que los clusters se alineen mejor con las categorías de ingresos verdaderas

# %% [markdown]
# # Experimento 2: Con indicadores disponibles 1960
# Todos los que puedan servir del año 1960
# /Users/miguelkiszkurno/Documents/TT1/data/indicadores_filtrados_1960.csv

# %% [markdown]
# # Experimento 3: Con indicadores disponibles en 2022 sin imputar
